# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
machine1 = pd.read_csv('C:/codeit/lab.csv', parse_dates =['Date','Time'])
machine1.describe()
# Out:
#        Concentration
# count    1892.000000
# mean        0.018301
# std         0.005899
# min         0.005000
# 25%         0.015000
# 50%         0.018000
# 75%         0.022000
# max         0.030000

# %%
# lab['Time-hour'] = lab['Time'].dt.hour

# lab[['Time-hour','Concentration']].head()

# # 잘못 짰어. 5일과 6일 분간이 없어지면서, 두 날의 hour가 중첩됐다

# %%
# plt.figure(figsize=(20,5)) # 됐따 냥냥
# sns.lineplot(x='Time-hour',y='Concentration',data=lab)

# # plt.figure(figsize=(20,5))
# # plt.title('Line Graph Indoor air status', fontsize = 20)
# # plt.ylabel('Concentration', fontsize=14)
# # plt.xlabel('Time', fontsize=14)
# plt.show()
# # plt.legend(fontsize = 12)

# # sns.pointplot(data = lab, x='Time',y='Concentration', figsize = (63,21))

# %%
machine1['Time-day'] = machine1['Date'].dt.day
machine1['Time-hour'] = machine1['Time'].dt.hour

machine1 = machine1[['Time-day','Time-hour','Concentration']]

machine1.tail()
# Out:
#       Time-day  Time-hour  Concentration
# 1887         6         23          0.006
# 1888         6         23          0.006
# 1889         6         23          0.006
# 1890         6         23          0.006
# 1891         6         23          0.006

# %%
machine1_5 = machine1.loc[machine1['Time-day'] == 5]
machine1_6 = machine1.loc[machine1['Time-day'] == 6]
machine1_6
# Out:
#       Time-day  Time-hour  Concentration
# 484          6          0          0.026
# 485          6          0          0.025
# 486          6          0          0.025
# 487          6          0          0.025
# 488          6          0          0.025
# 489          6          0          0.026
# 490          6          0          0.026
# 491          6          0          0.027
# 492          6          0          0.028
# 493          6          0          0.029
# 494          6          0          0.030
# 495          6          0          0.029
# 496          6          0          0.028
# 497          6          0          0.028
# 498          6          0          0.027
# 499          6          0          0.027
# 500          6          0          0.027
# 501          6          0          0.027
# 502          6          0          0.027
# 503          6          0          0.027
# 504          6          0          0.027
# 505          6          0          0.027
# ...

# %%
plt.figure(figsize=(20,10)) # 됐따 냥냥
sns.lineplot(x='Time-hour',y='Concentration',data=machine1_6)

# plt.figure(figsize=(20,5))
# plt.title('Line Graph Indoor air status', fontsize = 20)
# plt.ylabel('Concentration', fontsize=14)
# plt.xlabel('Time', fontsize=14)
plt.show()
# plt.legend(fontsize = 12)

# %%
# figure, ((ax1,ax2))=plt.subplots(nrows=1,ncols=2)

plt.figure(figsize=(20,5))
sns.lineplot(x='Time-hour',y='Concentration',data=machine1_5)

plt.figure(figsize=(20,5))
sns.lineplot(x='Time-hour',y='Concentration',data=machine1_6)

# %%
machine2 = pd.read_csv('C:/codeit/lab.csv', parse_dates =['Date','Time'])
machine2['Time-day'] = machine2['Date'].dt.day
machine2['Time-hour'] = machine2['Time'].dt.hour

machine2 = machine2[['Time-day','Time-hour','Concentration']]

machine2_5 = machine2.loc[machine2['Time-day'] == 5]
machine2_6 = machine2.loc[machine2['Time-day'] == 6]

plt.figure(figsize=(20,5))
sns.lineplot(x='Time-hour',y='Concentration',data=machine2_5)

plt.figure(figsize=(20,5))
sns.lineplot(x='Time-hour',y='Concentration',data=machine2_6)

# %%
plt.figure(figsize=(18,8))
sns.violinplot(machine2['Concentration'])
plt.figure(figsize=(18,8))
sns.violinplot(machine1['Concentration'])
